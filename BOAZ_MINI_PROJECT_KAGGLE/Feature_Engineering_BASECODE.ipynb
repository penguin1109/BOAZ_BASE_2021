# %% [markdown]
# ![2021-02-25 (2).png](data:image/png;base64,...)

# %% [markdown]
# ### EDA & FEATURE ENGINEERING
# 1. 데이터의 타입이 무엇인가?
# 2. 각 변수들이 의미하는 것이 무엇인가?
# 3. 중복된 변수가 있는가?
# 4. 결측치는 존재하는가? => 존재한다면 결측치를 그냥 제거할 것인가 0으로 처리할 것인가?
# 5. 숫자처럼 보이지만 문자인 것들이 존재하는가?
# 6. 데이터의 분포는 어떻게 되는가?
# 7. 갑자기 데이터의 비율이 변하는 시기가 있는가?
#
# 8. 다변량 변수가 있는가? => Feature 엔지니어링
#
# 9. histogram, boxplot, violinplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import
